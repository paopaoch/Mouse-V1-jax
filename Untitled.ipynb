# %%
import sim_utils, sim_utils_2
import matplotlib.pyplot as plt
import jax.numpy as np

# %%
mu = np.linspace(-0, 25, 200)
sigma = np.ones((200)) * 4

plt.plot(mu, sim_utils_2.Phi(mu, sigma),"--")
plt.plot(mu, sim_utils.Phi(mu, sigma), "r-")
plt.show()

# %% [markdown]
# ###
